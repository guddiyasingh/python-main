# %%
import logging

## create a logger for module

logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

##create a logger for module 2

logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

# configure logging settings

logging.basicConfig(
    level=logging.DEBUG,
    format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d-%H:%M:%S'
)

# %%
## log message with different loggeres

logger1.debug("This is debug message for module1")
logger2.warning("This is a warning message for module2")
logger2.error("This is an error message")
# Out:
# 2026-08-13-15:50:27 - module1 - DEBUG - This is debug message for module1
# 2026-08-13-15:50:27 - module2 - WARNING - This is a warning message for module2
# 2026-08-13-15:50:27 - module2 - ERROR - This is an error message
