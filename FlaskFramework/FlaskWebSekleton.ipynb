# %%
from flask import Flask

'''
It creates an instance of the Flask class,
which will be your WSGI (web Server Gateway Interface) application.

'''

###WSGI Application
app=Flask(__name__)

@app.route("/")
def welcome():
    return "Welcome to this"


if  __name__=="__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [30/Aug/2026 13:54:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2026 13:54:11] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# ## HTML with Flask WebApp

# %%
###WSGI Application
from flask import Flask, render_template

app=Flask(__name__)

@app.route("/")
def welcome():
    return "<html><H1>Welcome to the flask course</H1></html>"

@app.route("/index")
def index():
    return render_template('index.html')

if __name__=="__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (inotify)
# [IPKernelApp] WARNING | Kernel is running over TCP without encryption. All communication (including code and outputs) is sent in plain text and is susceptible to eavesdropping. Use IPC transport or launch with kernel manager-provisioned CurveZMQ keys to enable transport encryption.
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/guddiya-singh/Downloads/python-main-main/.venv/lib/python3.13/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#     ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/guddiya-singh/Downloads/python-main-main/.venv/lib/python3.13/site-packages/traitlets/config/application.py", line 1081, in launch_instance
#     app.initialize(argv)
#     ~~~~~~~~~~~~~~^^^^^^
#   File "/home/guddiya-singh/Downloads/python-main-main/.venv/lib/python3.13/site-packages/traitlets/config/application.py", line 118, in inner
#     return method(app, *args, **kwargs)
#   File "/home/guddiya-singh/Downloads/python-main-main/.venv/lib/python3.13/site-packages/ipykernel/kernelapp.py", line 760, in initialize
#     self.init_sockets()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/guddiya-singh/Downloads/python-main-main/.venv/lib/python3.13/site-packages/ipykernel/kernelapp.py", line 373, in init_sockets
#     self.shell_port = self._bind_socket(self.shell_socket, self.shell_port)
#                       ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/guddiya-singh/Downloads/python-main-main/.venv/lib/python3.13/site-packages/ipykernel/kernelapp.py", line 280, in _bind_socket
#     return self._try_bind_socket(s, port)
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^
#   File "/home/guddiya-singh/Downloads/python-main-main/.venv/lib/python3.13/site-packages/ipykernel/kernelapp.py", line 256, in _try_bind_socket
#     s.bind("tcp://%s:%i" % (self.ip, port))
#     ~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/guddiya-singh/Downloads/python-main-main/.venv/lib/python3.13/site-packages/zmq/sugar/socket.py", line 320, in bind
#     super().bind(addr)
#     ~~~~~~~~~~~~^^^^^^
#   File "zmq/backend/cython/_zmq.py", line 1009, in zmq.backend.cython._zmq.Socket.bind
#     _check_rc(rc)
#
#   File "zmq/backend/cython/_zmq.py", line 190, in zmq.backend.cython._zmq._check_rc
#     raise ZMQError(errno)
#
# zmq.error.ZMQError: Address already in use (addr='tcp://127.0.0.1:9007')
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
