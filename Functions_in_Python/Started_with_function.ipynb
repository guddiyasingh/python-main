# %% [markdown]
# Functions in Python
#
#
# Video Outline
#
#
#
# 1. Introduction to Function
# 2.Defining Function
# 3.Calling Function
# 4.Function Parameters
# 5.Default Parameters
# 6.Variable-Length Arguments
# 7.Retrun Statment
#
#
#
# Introduction to Functions
#
# Definition:
#
# A function is a block of code that performs a specific task . Function help in organizing code, reusing code , and improving readablitiy.

# %%
## syntax

def function_name(parameters):
    """Docstring"""
    # Functions body
    return expression

# %%
## why functions?

num=24

if num%2==0:
    print("The number is even")
else:
    print("the num")
# Out:
# The number is even

# %%
def even_or_odd(num):
    """This function finds even or odd"""
    if num%2==0:
        print("the number is even")
    else:
        print("the number is odd")

# %%
## call this function

even_or_odd(24)
# Out:
# the number is even

# %%
## function with multiple parameters

def add(a,b):
    return a+b

result = add(2,4)
print(result)
# Out:
# 6

# %%
## Default Parameters

def greet(name="Guest"):
    print(f"Hello {name} Welcome To the paradise")
greet("Krish")
# Out:
# Hello Krish Welcome To the paradise

# %%
### Variable Length Arguments

## Positional And Keywords arguments

def print_numbers(*krish):
    for number in krish:
        print(number)

# %%
print_numbers(1,2,3,4,5,6,7,8,"Krish")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# Krish

# %%
## Keywords Arguments

def print_details(**kwords):
    for key,value in kwords.items():
        print(f"{key}:{value}")

# %%
print_details(name="krish",ages=32,country="india")
# Out:
# name:krish
# ages:32
# country:india

# %%
def print_details(*args,**kwords):
    for val in args:
        print(f"positiional argument:{val}")
    for key,value in kwords.items():
        print(f"{key}:{value}")

# %%
print_details(1,2,3,4,"krish", name="krish",age=32,country="India")
# Out:
# positiional argument:1
# positiional argument:2
# positiional argument:3
# positiional argument:4
# positiional argument:krish
# name:krish
# age:32
# country:India

# %%
def multiply(a,b):
    return a*b
multiply(2,5)
# Out:
# 10

# %%
def temp(c):
    return (25*9/5)+32
temp(100)
# Out:
# 77.0

# %%
def temp1(*c):
    for val in c:
        print(f"{(val*9/5)+32}")

# %%
temp1(23,34,45,66)
# Out:
# 73.4
# 93.2
# 113.0
# 150.8

# %%
def convert_temperature(temp,unit):
    """This function converts temprature between celsius and"""
    if unit=='C':
        return temp*9/5+32 ## Celsius To Fahrenheit
    elif unit=="F":
        return (temp-32)*5/9 ## Fahrenheit to celsius
    else:
        return None
    
print(convert_temperature(25,'C'))
print(convert_temperature(77,"F"))
# Out:
# 77.0
# 25.0

# %% [markdown]
# Example 2 : Password Strength Checker

# %%
def password_strength(password):
    for strenth in password:
        if strenth==10:
            return("password strenght is correct")
        elif strenth<10:
            return("This password strenght is short")
        else:
            return("Password is not correct")

# %%
print(password_strength())
print(password_strength("staticmethod"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(password_strength())
#       2 print(password_strength("staticmethod"))
#
# TypeError: password_strength() missing 1 required positional argument: 'password'

# %%
def password_strength(password):
    if len(password) == 10:
        return "password strength is correct"
    elif len(password)<10:
        return "This password strength is sort"
    else:
        return "password is strong"

# %%
print(password_strength("name"))
# Out:
# This password strength is sort

# %%
def is_strong_password(password):
    """This function checks if the password is strong or not"""
    if len(password)<8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char in '!@#$%^&*()_+' for char in password):
     return False
    return True

# %%
## Calling the function

print(is_strong_password("Guddiya@1847"))
# Out:
# True

# %%
total=0


cart = {

    "item1":{"name":"shoes", "price":229 ,"quantity":4},
    "item 2": {"name":"paint","price":500,"quantity":6},
    "item3": {"name":"shirt","price":300,"quantity":3}
}


for item in cart.values():
    total+=item["price"]
print("Total Price:",total)
# Out:
# Total Price: 1029

# %%
# for item in cart.values():
#     total +=item["price"]
# print("Total Price:",total)

# %%
# functions for calculating total cost of item in shopping car

def calculate_total_cost(cart):

    total_cost=0
    for item in cart:
        total_cost+=item["price"]*item["quantity"]

    return total_cost  


cart = [

   {"name":"shoes", "price":229 ,"quantity":4},
    {"name":"paint","price":500,"quantity":6},
     {"name":"shirt","price":300,"quantity":3}
]

# %%
print(calculate_total_cost(cart))
# Out:
# 4816

# %%
s = input("Enter a string:")

if s==s[::-1]:
    print("palindrome")
else:
    print("Not a palindrome")
# Out:
# Not a palindrome

# %%
def palindrom(number):

 return str(number)==str(number)[::-1]

# %%
print(palindrom(121))
# Out:
# True

# %%
def is_palindrome(s):
    s=s.lower().replace(" ","")
    return s==s[::-1]



print(is_palindrome("A man a plan a canal Panama"))
print(is_palindrome("Hello"))
# Out:
# False
# False

# %%
# loop vs  recursion



# Loop

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Recursion

def count(n):
    if n==0:
       return
    print(n)
    count(n - 1)


count(5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# 5. Calculate the factorial of a number using recursion

# %%
def factorial(n):
    if n==0:
        return 1
    else:
        return n*factorial(n-1)
print(factorial(5))
# Out:
# 120

# %% [markdown]
# 6. A Function to read a file and count the frequeny of each word

# %%
# def count_word_frequency(file_path):
#     word_count={}
#     with open(file_path, 'r') as file:
#         for line in file:
#             words = line.strip().split()
#             for word in words:
#                 word_count[word] = word_count.get(word, 0) + 1
#     return word_count



def count_word_frequency(file_path):
    word_count={}
    with open(file_path, 'r') as file:
        for line in file:
            words = line.strip().split()
            for word in words:
                word_count[word] = word_count.get(word, 0) + 1
    return word_count

# %%
count_word_frequency("sample.txt")
# Out:
# {'Hello': 1, 'world': 1, 'earth': 1, 'is': 1, 'round': 1}

# %%
def celesious_to_fahrenheit(c):
    f = (9/5*c)+32
    return f

print(celesious_to_fahrenheit(5))
# Out:
# 41.0

# %%
# Calculate the area of rectangle
def calculate_area(length, breadth):
 area = length * breadth
 return area

print(calculate_area(5,10))
# Out:
# 50

# %%
import math

def lift_rounds(n,capacity):
    rounds = math.ceil(n/capacity)
    return rounds
print(lift_rounds(100,30))
# Out:
# 4
