# %%
user = input("Enter your name: ")
print(f"Hello, {user}!")
lst=[]
for i in range(user):
    lst.append(user[i])
print(lst)
# Out:
# Hello, you!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 user = input("Enter your name: ")
#       2 print(f"Hello, {user}!")
#       3 lst=[]
# ----> 4 for i in range(user):
#       5     lst.append(user[i])
#       6 print(lst)
#
# TypeError: 'str' object cannot be interpreted as an integer
