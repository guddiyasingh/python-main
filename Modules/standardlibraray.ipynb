# %%
import array 
arr= array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random 

import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 10
# apple

# %%
### File And Directory

import os 
print(os.getcwd)
# Out:
# <built-in function getcwd>

# %%
os.mkdir('sheet_dir')

# %%
# High level operations on files and collection of files

import shutil

shutil.copyfile('notes.txt', 'destiny.txt')
# Out:
# 'destiny.txt'
