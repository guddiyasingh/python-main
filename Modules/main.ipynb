# %%
import calculator


result = calculator.add(3,4)
print(result)
# Out:
# 7

# %%
import calculator

result = calculator.sub(5,3)
print(result)
# Out:
# 2

# %%
from datetime import datetime

now = datetime.now()
print(f"Current year: {now.year}")
# Out:
# Current year: 2026

# %%
import json

user_data = {"name": "Alice", "score": 42}
json_string = json.dumps(user_data) # Converts dictionary to text string
print(json_string)
# Out:
# {"name": "Alice", "score": 42}

# %%
import random

choices = ['rock', 'paper', 'scissors']
computer_move = random.choice(choices)
print(computer_move)
# Out:
# rock

# %%
# This creates (or overwrites) 'notes.txt'
with open("notes.txt", "w") as file:
    file.write("Remember to buy milk.\n")
    file.write("Finish the Python project.")

# %%
# This opens and reads the file we just made
with open("notes.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Remember to buy milk.
# Finish the Python project.

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from package.maths import addition
addition(2,3)
# Out:
# 5

# %%
from package import maths 
maths.addition(2,3)
# Out:
# 5

# %% [markdown]
# Standard Library
#
# Python's Standard Library is a vast collection of modules and packages that come bundled with python, provinding a wide range of functionalities out of box. Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.

# %%
import array 
arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
## random

import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 1
# banana

# %%
### File And Directory Access

import os

print(os.getcwd())
# Out:
# /home/vishnu-singh/Documents/guddiya/python-main/Modules

# %%
os.mkdir('test_dir')

# %%
## High level operations on files and collection of files

import shutil
shutil.copyfile('notes.txt','destination.txt')
