# %% [markdown]
# Assignment 1 : Reading a File
#
# Write a functions that reads the contents of a file named sample.txt and prints each line.

# %%
with open("example.txt","r") as file:
    content = file.read()
    print(content)
# Out:
# Hello World!
# this is a new line.thiis is a old lineAppendAppend operation taking place!
# Hello World!
# this is a new line.thiis is a old lineFirst line
# Second line
# Third line
# Hello World!
# this is a new line.thiis is a old lineHello World!
# this is a new line.thiis is a old lineHello World!
# this is a new line.thiis is a old lineAppend operation taking place!
# This is a new line added to the file.
# This is a new line added to the file.
# hy
# hy

# %%
with open("output.txt","w") as file:
    content = "Hello, World!"
    name = "Guddiya Singh"
    file.write(content)
    file.write("\n")
    file.write(name)
    print("Content written to output.txt")
# Out:
# Content written to output.txt
