# %%
import os

os.chdir("C:/Users/Guddiya/Documents")
print(os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2
# ----> 3 os.chdir("C:/Users/Guddiya/Documents")
#       4 print(os.getcwd())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Guddiya/Documents'

# %%
import os

if os.path.exists("example.txt"):
    print("File exists")
else:
    print("File not found")
# Out:
# File exists

# %%
from pathlib import Path

file_path = Path("files") / "data.txt"

print(file_path)
# Out:
# files/data.txt

# %%
from pathlib import Path

file_path = Path("files") / "example.txt"

with file_path.open("r") as file:
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       1 from pathlib import Path
#       2
#       3 file_path = Path("files") / "example.txt"
#       4
# ----> 5 with file_path.open("r") as file:
#       6     print(file.read())
#
# File /usr/lib/python3.13/pathlib/_local.py:539, in Path.open(self, mode, buffering, encoding, errors, newline)
#     537 if "b" not in mode:
#     538     encoding = io.text_encoding(encoding)
# --> 539 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'files/example.txt'

# %%
# create a new directory
import os

new_directory="package"
os.mkdir(new_directory)
print(f"Directory created: {new_directory}")
# Out:
# Directory created: package

# %%
# Listing files and directory
import os

items = os.listdir('.')
print(items)
# Out:
# ['user_file.csv', 'Assignment.ipynb', 'package', 'output.txt', 'File_operations.ipynb', 'examle.txt', 'example.txt', 'copy.txt', 'file_path.ipynb', 'example.bin']
