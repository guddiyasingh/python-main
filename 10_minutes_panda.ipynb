# %% [markdown]
# Object Creation

# %% [markdown]
# Creating a series by passing a list of values,letting panda create default Range Index

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1,3,5, np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Creating a dataframe by passing a numpy array with a datetime index using date_range() and labeled columns.

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[us]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.282646  0.912627  0.524745  0.826490
# 2013-01-02 -1.200173  0.505088 -1.084961  0.515620
# 2013-01-03  1.472587 -1.024150 -0.730165  0.612623
# 2013-01-04 -0.496127  0.055245  0.542751  0.873279
# 2013-01-05 -0.920666 -1.828383 -0.502787  1.370108
# 2013-01-06 -0.397056 -1.675978 -1.247060 -1.418620

# %% [markdown]
# Creating a dataframe by passings a dictionary of objects where the keys are the column lables and the vlaues are the column values.

# %%
df2 = pd.DataFrame(
    {
        "A":1.0,
        "B":pd.Timestamp("20130102"),
        "C":pd.Series(1, index=list(range(4)),dtype="float32"),
        "D":np.array([3]*4,dtype="int32"),
        "E":pd.Categorical(["test","train","test","train"]),
        "F":"foo",

    }
)

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# The columns of the resulting dtataframe have different dtypes

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[us]
# C           float32
# D             int32
# E          category
# F               str
# dtype: object

# %% [markdown]
# If you're using IPython, tab completion for column names(as well as public attributes)is automatically enabled.Here's subset of the attributes that will be completed:
#
# In [12]:df2.<TAB> #noqa:E225, E999
#
# df2.A
# df2.abs
# df2.add_prefix
# df2.add_suffix
# df2.align
# df2.all
# df2.any
# df2.append
# df2.append
# df2.apply
# df2.B
# df2.diff
#
# df2.bool
# df2.boxplot
# df2.C
# df2.clip
# df2.count
# df2.copy
# df2.combine
# df2.describe
# df2.duplicated

# %% [markdown]
# As you can see, the columns A , B, C , D are automatically tab completed. E and F are there as well; the rest of the attributes have been truncated for brevity

# %% [markdown]
# Viewing data

# %% [markdown]
# Use dataframe.head() and dataframe.tail() to view the top and bottom rows of the frame respectively:

# %%
df2.head(2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.tail(2)
# Out:
#      A          B    C  D      E    F
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# Display the DataFrame.index or DataFrame.columns():

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='str')

# %% [markdown]
# Return a NumPy represrntation of the underlying with DataFrame.to_numpy() without the index or column labels:

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %% [markdown]
# describe() shows a quick statisic summary of your data:

# %%
df2.describe()
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2013-01-02 00:00:00  1.0  3.0
# min    1.0  2013-01-02 00:00:00  1.0  3.0
# 25%    1.0  2013-01-02 00:00:00  1.0  3.0
# 50%    1.0  2013-01-02 00:00:00  1.0  3.0
# 75%    1.0  2013-01-02 00:00:00  1.0  3.0
# max    1.0  2013-01-02 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %% [markdown]
# Transposing your data:

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2013-01-02 00:00:00  2013-01-02 00:00:00  2013-01-02 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F                  foo                  foo                  foo
#
#                      3
# A                  1.0
# B  2013-01-02 00:00:00
# C                  1.0
# D                    3
# E                train
# F                  foo

# %% [markdown]
# DataFrame.sort_index() sorts by an axis:

# %%
df2.sort_index(axis=2, ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Downloads/python-main-main/.venv/lib/python3.13/site-packages/pandas/core/generic.py:525, in NDFrame._get_axis_number(cls, axis)
#     523             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     524         except KeyError as err:
# --> 525             raise ValueError(
#     526                 f"No axis named {axis} for object type {cls.__name__}"
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df2.sort_index(axis=2, ascending=False)
#
# File ~/Downloads/python-main-main/.venv/lib/python3.13/site-packages/pandas/core/frame.py:8546, in DataFrame.sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    8542         b  2
# ...

# %% [markdown]
# DataFrame.sort_values() sorts by values:

# %%
df2.sort_values(by="B")
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.iloc()

# %% [markdown]
# Getitem([])
#
# For a dataFrame, passing a single label selects a column and yields a series:

# %%
df2["A"]
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %% [markdown]
# If the label only containes letter, numbers, and ubderscores, you can alternatively use the column name attribute:

# %%
df2.A
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %% [markdown]
# Passing alist of column labels selects multiple columns, which can be useful for getting a subset/rearranging:

# %%
df2[['B',"A"]]
# Out:
#            B    A
# 0 2013-01-02  1.0
# 1 2013-01-02  1.0
# 2 2013-01-02  1.0
# 3 2013-01-02  1.0

# %% [markdown]
# For a DataFrame, passing a slice: selects matching row:

# %%
df2[1:3]
# Out:
#      A          B    C  D      E    F
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo

# %% [markdown]
# Selection by label
#
# see more in Selection by label using DataFrame.loc() or DataFrame.at().

# %% [markdown]
# Selecting a row matching a label:

# %%
df2.loc[[0]]
# Out:
#      A          B    C  D     E    F
# 0  1.0 2013-01-02  1.0  3  test  foo

# %% [markdown]
# Selecting all rows (:) with a select column labels

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2013-01-01 -0.396151  2.014339
# 2013-01-02  1.658322  0.902785
# 2013-01-03  0.097010 -1.830312
# 2013-01-04 -0.335893 -0.579585
# 2013-01-05 -0.794192  0.750310
# 2013-01-06  0.388137  0.109297

# %% [markdown]
# For label slicing, both endpoints are include:

# %%
df.loc["20130103":"20130104",["A","B"]]
# Out:
#                    A         B
# 2013-01-03  0.097010 -1.830312
# 2013-01-04 -0.335893 -0.579585

# %% [markdown]
# Selecting a single row and column label returns a scaler:

# %%
df.loc[dates[0],"A"]
# Out:
# np.float64(-0.3961507355425335)

# %% [markdown]
# For getting fast access to a scaler(equivalent to the prior method)

# %%
df.at[dates[0],"A"]
# Out:
# np.float64(-0.3961507355425335)

# %% [markdown]
# Selection by position
#
# Select via the position of the passed integers:

# %%
df2.iloc[2]
# Out:
# A                    1.0
# B    2013-01-02 00:00:00
# C                    1.0
# D                      3
# E                   test
# F                    foo
# Name: 2, dtype: object

# %% [markdown]
# integer slice acts similar to NumPy/Python

# %%
df2.iloc[3:2,0:2]
# Out:
# Empty DataFrame
# Columns: [A, B]
# Index: []

# %% [markdown]
# Lists of integer position locations:

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02  1.658322 -0.079600
# 2013-01-03  0.097010 -0.659378
# 2013-01-05 -0.794192  0.043921

# %% [markdown]
# For slicing rows explicity:

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02  1.658322  0.902785 -0.079600  0.607789
# 2013-01-03  0.097010 -1.830312 -0.659378  1.483496

# %% [markdown]
# For slicing columns explicity:

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01  2.014339 -0.459879
# 2013-01-02  0.902785 -0.079600
# 2013-01-03 -1.830312 -0.659378
# 2013-01-04 -0.579585 -1.004141
# 2013-01-05  0.750310  0.043921
# 2013-01-06  0.109297 -0.841985

# %%
# for getting a value explicity

# %%
df.iloc[1,1]
# Out:
# np.float64(0.9027854802658536)

# %% [markdown]
# Boolean indexing
# Selecting rows where df.A is greater

# %%
df[df["A"]>0]
# Out:
#                    A         B         C         D
# 2013-01-02  1.658322  0.902785 -0.079600  0.607789
# 2013-01-03  0.097010 -1.830312 -0.659378  1.483496
# 2013-01-06  0.388137  0.109297 -0.841985  0.161173

# %% [markdown]
# Selecting values from a dataframe where a boolean condtion is met:

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN  2.014339       NaN  1.018157
# 2013-01-02  1.658322  0.902785       NaN  0.607789
# 2013-01-03  0.097010       NaN       NaN  1.483496
# 2013-01-04       NaN       NaN       NaN       NaN
# 2013-01-05       NaN  0.750310  0.043921       NaN
# 2013-01-06  0.388137  0.109297       NaN  0.161173

# %% [markdown]
# Using isin() method for filtering

# %%
df2=df.copy()
df2["E"]=["one","one","two","three","four","three"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.396151  2.014339 -0.459879  1.018157    one
# 2013-01-02  1.658322  0.902785 -0.079600  0.607789    one
# 2013-01-03  0.097010 -1.830312 -0.659378  1.483496    two
# 2013-01-04 -0.335893 -0.579585 -1.004141 -0.426638  three
# 2013-01-05 -0.794192  0.750310  0.043921 -1.474908   four
# 2013-01-06  0.388137  0.109297 -0.841985  0.161173  three

# %% [markdown]
# SETTING

# %% [markdown]
# Setting a new column automatically aligns the data by the indexes:

# %%
s1 = pd.Series([1,2,3,4,5,6],index=pd.date_range("20130102",periods=6))
df["F"]=s1
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  0.524745  5.0  NaN
# 2013-01-02 -1.200173  0.505088 -1.084961  5.0  1.0
# 2013-01-03  1.472587 -1.024150 -0.730165  5.0  2.0
# 2013-01-04 -0.496127  0.055245  0.542751  5.0  3.0
# 2013-01-05 -0.920666 -1.828383 -0.502787  5.0  4.0
# 2013-01-06 -0.397056 -1.675978 -1.247060  5.0  5.0

# %% [markdown]
# Setting values by label:

# %%
df.at[dates[0],"A"]=0
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  0.524745  5.0  NaN
# 2013-01-02 -1.200173  0.505088 -1.084961  5.0  1.0
# 2013-01-03  1.472587 -1.024150 -0.730165  5.0  2.0
# 2013-01-04 -0.496127  0.055245  0.542751  5.0  3.0
# 2013-01-05 -0.920666 -1.828383 -0.502787  5.0  4.0
# 2013-01-06 -0.397056 -1.675978 -1.247060  5.0  5.0

# %%
# Setting values by position:
df.iat[0,1]=0

# %%
# Setting by assiging with a Numpy array:
df.loc[:,"D"]=np.array([5]*len(df))

# %% [markdown]
# The result of the prior setting operations:

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  0.524745  5.0  NaN
# 2013-01-02 -1.200173  0.505088 -1.084961  5.0  1.0
# 2013-01-03  1.472587 -1.024150 -0.730165  5.0  2.0
# 2013-01-04 -0.496127  0.055245  0.542751  5.0  3.0
# 2013-01-05 -0.920666 -1.828383 -0.502787  5.0  4.0
# 2013-01-06 -0.397056 -1.675978 -1.247060  5.0  5.0

# %%
# A where operation with setting:
df2=df.copy()
df2

df2[df2>0]=-df2
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.524745 -5.0  NaN
# 2013-01-02 -1.200173 -0.505088 -1.084961 -5.0 -1.0
# 2013-01-03 -1.472587 -1.024150 -0.730165 -5.0 -2.0
# 2013-01-04 -0.496127 -0.055245 -0.542751 -5.0 -3.0
# 2013-01-05 -0.920666 -1.828383 -0.502787 -5.0 -4.0
# 2013-01-06 -0.397056 -1.675978 -1.247060 -5.0 -5.0

# %% [markdown]
# MISSING DATA

# %% [markdown]
# For NumPy data types, np.nan represents missing data.It is by default not included in computations .
#
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data:

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1],"E"]=1
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  0.524745  5.0  NaN  1.0
# 2013-01-02 -1.200173  0.505088 -1.084961  5.0  1.0  1.0
# 2013-01-03  1.472587 -1.024150 -0.730165  5.0  2.0  NaN
# 2013-01-04 -0.496127  0.055245  0.542751  5.0  3.0  NaN

# %% [markdown]
# DataFrame.dropna() drops any rows that have missing data:

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    F    E
# 2013-01-02 -1.200173  0.505088 -1.084961  5.0  1.0  1.0

# %% [markdown]
# DataFrame.fillna() fills missing data:

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  0.524745  5.0  5.0  1.0
# 2013-01-02 -1.200173  0.505088 -1.084961  5.0  1.0  1.0
# 2013-01-03  1.472587 -1.024150 -0.730165  5.0  2.0  5.0
# 2013-01-04 -0.496127  0.055245  0.542751  5.0  3.0  5.0

# %% [markdown]
# isna() gets the boolean mask where values are nan:

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# Operations

# %% [markdown]
# Stats
#
# Operations in genaral exclude missing data.
# calculate the mean value for each column:
