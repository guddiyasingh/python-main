# %%
## Integer Example

age = 35
type(age)
# Out:
# int

# %%
## floating point number example
height=5.9
print(height)
print(type(height))
# Out:
# 5.9
# <class 'float'>

# %%
## string data type example
name = "Vishnu"
print(name)
print(type(name))
# Out:
# Vishnu
# <class 'str'>

# %%
## boolean datatype

is_true=True
type(is_true)
# Out:
# bool

# %%
a = 10
b= 20

type(a==b)
# Out:
# bool

# %%
result= "Hello" + str(11)
print(result)
# Out:
# Hello11
