# %%
## Basic syntax Rules In python
## Case sensitivity - python is case sensitive

name = "John"
Name = "Doe"

print(name)
print(Name)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 ## Basic syntax Rules In python
#       2 ## Case sensitivity - python is case sensitive
# ----> 4 name = "John"
#       5 Name = "Doe"
#       7 print(name)
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
# ---> 69 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1481, in _pydevd_sys_monitoring_cython._line_event()
# -> 1481 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1523, in _pydevd_sys_monitoring_cython._internal_line_event()
# -> 1523 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1324, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
# -> 1324 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1961, in _pydevd_sys_monitoring_cython._do_wait_suspend()
# -> 1961 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/Documents/guddiya/python/myenv/lib/python3.13/site-packages/debugpy/_vendored/pydevd/pydevd.py:2199, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2196             from_this_thread.append(frame_custom_thread_id)
#    2198     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2199         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2201 frames_list = None
#    2203 if keep_suspended:
#    2204     # This means that we should pause again after a set next statement.
#
# File ~/Documents/guddiya/python/myenv/lib/python3.13/site-packages/debugpy/_vendored/pydevd/pydevd.py:2268, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2265                 queue.put(internal_cmd)
#    2266                 wait_timeout = TIMEOUT_FAST
# -> 2268         notify_event.wait(wait_timeout)
#    2269         notify_event.clear()
#    2271 finally:
#
# File /usr/lib/python3.13/threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File /usr/lib/python3.13/threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
## This is a single line comment
print("Hello world")  # This is an inline comment
# Out:
# Hello world

# %%
## Line continuation character

total = 1+2+3+5+6+7+\
4+5+6
print(total)
# Out:
# 39

# %%
## Multiple Statments on a single line
x = 5; y=10; z=x+y
print(z)
# Out:
# 15

# %% [markdown]
# ## Understand Sementics In python
# # variable assigment
# age = 32 ## age is an integer
# name = "Vishnu" ## name is a string
# height = 5.9 ## height is a float
#
# type(age)

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Inference
variable = 10
print(type(variable))
variable ="krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age = 32
if age >= 30:
    print(age)
# Out:
# 32

# %%
## Code examples of indentation

if True:
    print("Correct Indentation")
    if False:
        print("This ont print")
    print("This will print")

print("This is outside the if block")
# Out:
# Correct Indentation
# This will print
# This is outside the if block

# %%
# VARIABLES IN PYTHON

# %%
## Declaring And Assigining Variables

age=29
height=5.9
name = "Vishnu"
is_student = True

## printing the variables
print("age:",age)
print("height:",height)
print("name:",name)
# Out:
# age: 29
# height: 5.9
# name: Vishnu

# %%
## Naming Conventions
# 1. Variable names must start with a letter or an underscore
# 2.Variables name should be descriptive
# 3.Variables case sensitive

# Valid variable names

first_name = "Vishnu"
last_name = "Singh"

# %%
## Understanding Variable types
## Python is a dynamically typed , type of variable is determined at runtime
age = 29 #int
height = 5.9 # float
name = "Vishnu" # string
is_student = True # boolean

print(type(age))

# %%
## Type Checking and Conversion
type(height)
# Out:
# float

# %%
age = 25
print(type(age))

#Type conversion
age_str = str(age)
print(age_str)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# 25
# <class 'str'>

# %%
# Dynamic Typing
## Python allows the type of a variable to  change as the program executes
var = 10
print(var,type(var))

var = "Hello"
print(var,type)
# Out:
# 10 <class 'int'>
# Hello <class 'type'>

# %%
### simple calculator
num1 = float(input("Enter first number:"))
num2 = float(input("Enter seond number:"))

sum = num1 + num2
difference = num1 - num2
product  = num1 * num2
quotient = num1 / num2

print("Sum:",sum)
print("Difference:",difference)
print("Product:",product)
print("Quotient:",quotient)
# Out:
# Sum: 3.0
# Difference: -1.0
# Product: 2.0
# Quotient: 0.5
